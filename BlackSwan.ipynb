# %% [markdown]
# <a href="https://colab.research.google.com/github/celinaLind/market-anomaly-detection/blob/main/BlackSwan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exploratory Data Analysis (EDA)
# A method of analyzing datasets to understand their main characteristics
# Through:
# - data summarization
# - pattern detection
# - finding relationships in the data
#
# #### **Task 1: Data Pre-processing**
# Clean and prepare raw data for feature engineering
#
# #### **Task 2: Analyze Data**
#
# #### **Task 3: Visualize Data-Univariate Plots**
#
# #### **Task 4: Visualize Data-Multivariate Plots**

# %%
# Step 1: Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore') # these are warnings to ignore

# %% [markdown]
# ### Step 2: Reading the Dataset
#
# ##### CSV Files
# A tabular format of the data
#
# - can be easily accessed and converted to a DataFrame
#
# using the **pd.read_csv(fileName)** function returns the read data as a DataFrame

# %%
# Step 2: Reading the Dataset
data = pd.read_csv('FinancialMarketData-EWS.csv')
# download_data = pd.read_csv('FinancialMarketData-Download.csv')

# %% [markdown]
# ### Step 3: Analyze Data (at high lvl)

# %%
data.shape
# Display the number of Observations (rows) and features (columns) in a dataset
# Result = (#Rows, #Columns)
# Out:
# (1111, 44)

# %%
download_data.shape
# Out:
# (1154, 60)

# %%
data.head()
# Display the top 5 observations
# Out:
#    Y       Data  XAU BGNL  ECSURPUS    BDIY     CRY     DXY     JPY    GBP  \
# 0  0  1/11/2000    283.25     0.077  1388.0  157.26  100.56  105.86  1.646
# 1  0  1/18/2000    287.65     0.043  1405.0  165.01  101.86  105.47  1.638
# 2  0  1/25/2000    287.15     0.135  1368.0  167.24  102.41  106.04  1.650
# 3  0   2/1/2000    282.75     0.191  1311.0  166.85  104.92  107.85  1.611
# 4  1   2/8/2000    298.40     0.312  1277.0  165.43  104.22  109.30  1.611
#
#      Cl1  ...  LP01TREU  EMUSTRUU  LF94TRUU     MXUS    MXEU     MXJP    MXBR  \
# 0  25.77  ...   116.464   230.527   123.762  1416.12  127.75   990.59  856.76
# 1  28.85  ...   117.267   231.377   123.762  1428.79  129.50   993.98  925.22
# 2  28.28  ...   117.995   232.390   123.762  1385.93  126.48   974.83  886.93
# 3  28.22  ...   120.510   231.942   122.328  1385.31  129.19  1007.12  842.60
# 4  28.02  ...   118.791   237.812   122.328  1411.95  134.67  1034.58  945.15
#
#      MXRU    MXIN   MXCN
# ...

# %%
data.tail()
# Display last 5 observations
# Out:
#       Y       Data  XAU BGNL  ECSURPUS    BDIY       CRY     DXY     JPY  \
# 1106  0  3/23/2021   1727.96     0.339  2271.0  184.5022  92.336  108.72
# 1107  0  3/30/2021   1685.56     0.303  2103.0  184.8741  93.297  110.29
# 1108  0   4/6/2021   1743.28     0.440  2092.0  185.8393  92.335  109.88
# 1109  0  4/13/2021   1742.69     0.467  2140.0  188.1368  91.852  109.19
# 1110  0  4/20/2021   1779.72     0.492  2432.0  193.8035  91.147  108.09
#
#          GBP    Cl1  ...  LP01TREU  EMUSTRUU  LF94TRUU     MXUS    MXEU  \
# 1106  1.3760  57.76  ...  427.7972  1249.403  389.8500  3800.77  140.32
# 1107  1.3719  60.55  ...  428.6578  1242.264  385.8145  3835.96  142.76
# 1108  1.3822  59.33  ...  430.6649  1250.256  390.6819  3955.16  144.13
# 1109  1.3737  60.18  ...  430.4087  1252.563  390.3848  4027.05  144.23
# 1110  1.3951  62.50  ...  431.5528  1261.678  395.3388  4043.69  146.39
#
#          MXJP     MXBR    MXRU     MXIN    MXCN
# ...

# %%
data.info()
# Provides column names, # of columns, data type,
# data having null/not null, memory usage of dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1111 entries, 0 to 1110
# Data columns (total 44 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Y          1111 non-null   int64
#  1   Data       1111 non-null   object
#  2   XAU BGNL   1111 non-null   float64
#  3   ECSURPUS   1111 non-null   float64
#  4   BDIY       1111 non-null   float64
#  5   CRY        1111 non-null   float64
#  6   DXY        1111 non-null   float64
#  7   JPY        1111 non-null   float64
#  8   GBP        1111 non-null   float64
#  9   Cl1        1111 non-null   float64
#  10  VIX        1111 non-null   float64
#  11  USGG30YR   1111 non-null   float64
#  12  GT10       1111 non-null   float64
#  13  USGG2YR    1111 non-null   float64
#  14  USGG3M     1111 non-null   float64
#  15  US0001M    1111 non-null   float64
#  16  GTDEM30Y   1111 non-null   float64
#  17  GTDEM10Y   1111 non-null   float64
#  18  GTDEM2Y    1111 non-null   float64
# ...

# %%
download_data.head()
# Out:
#         Unnamed: 0 Unnamed: 1      Unnamed: 2                    Unnamed: 3  \
# 0  EURUSDV3M Index        NaN             NaN  Fixed Income, MM & Interbank
# 1              NaN        NaN  Show/Hide data                             S
# 2              676        NaN            Name                           NaN
# 3              NaN        NaN  Index Currency                           NaN
# 4              NaN        NaN          Ticker               XAU BGNL Curncy
#
#        Unnamed: 4  Unnamed: 5 Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0             NaN         NaN        NaN         NaN         NaN         NaN
# 1               H           H          H           H           H           H
# 2             NaN         NaN        NaN         NaN         NaN         NaN
# 3             NaN         NaN        NaN         NaN         NaN         NaN
# 4  ECSURPUS Index  BDIY Index  CRY Index  DXY Curncy  JPY Curncy  GBP Curncy
#
# ...

# %%
download_data = pd.read_csv("FinancialMarketData-Download.csv")
download_data.columns = download_data.iloc[4]  # Set the column names to the values in the ticker row
# download_data = download_data[:]  # Drop the first row (which is now the header)

# %%
download_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1154 entries, 0 to 1153
# Data columns (total 60 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nan              10 non-null     object
#  1   nan              8 non-null      object
#  2   Ticker           1152 non-null   object
#  3   XAU BGNL Curncy  1152 non-null   object
#  4   ECSURPUS Index   1113 non-null   object
#  5   BDIY Index       1150 non-null   object
#  6   CRY Index        1150 non-null   object
#  7   DXY Curncy       1150 non-null   object
#  8   JPY Curncy       1150 non-null   object
#  9   GBP Curncy       1150 non-null   object
#  10  Cl1 Comdty       1150 non-null   object
#  11  VIX Index        1150 non-null   object
#  12  USGG30YR Index   1150 non-null   object
#  13  GT10 Govt        1150 non-null   object
#  14  USGG2YR Index    1150 non-null   object
#  15  USGG3M Index     1150 non-null   object
# ...

# %%
download_data.nunique()
# Out:
# 4
# NaN                  10
# NaN                   8
# Ticker             1152
# XAU BGNL Curncy    1129
# ECSURPUS Index      749
# BDIY Index          961
# CRY Index          1133
# DXY Curncy         1112
# JPY Curncy          997
# GBP Curncy          560
# Cl1 Comdty         1084
# VIX Index           891
# USGG30YR Index      993
# GT10 Govt          1004
# USGG2YR Index       944
# USGG3M Index        644
# US0001M Index       719
# GTDEM30Y Govt      1011
# GTDEM10Y Govt      1025
# GTDEM2Y Govt        978
# EONIA Index         585
# GTITL30YR Corp      979
# GTITL10YR Corp      987
# GTITL2YR Corp      1005
# GTJPY30YR Corp      809
# GTJPY10YR Corp      760
# GTJPY2YR Corp       558
# GTGBP30Y Govt       913
# GTGBP20Y Govt       955
# GTGBP2Y Govt        966
# LUMSTRUU Index     1143
# LMBITR Index       1146
# LUACTRUU Index     1142
# LF98TRUU Index     1136
# LG30TRUU Index     1149
# LP01TREU Index     1145
# EMUSTRUU Index     1149
# LF94TRUU Index      960
# ...

# %%
data.nunique()
# Check for duplications
# Result counts the number of distinct elements in each column
# Out:
# Y               2
# Data         1111
# XAU BGNL     1092
# ECSURPUS      747
# BDIY          936
# CRY          1095
# DXY          1078
# JPY           967
# GBP           577
# Cl1          1045
# VIX           864
# USGG30YR      958
# GT10          967
# USGG2YR       921
# USGG3M        625
# US0001M       703
# GTDEM30Y      978
# GTDEM10Y      989
# GTDEM2Y       944
# EONIA         568
# GTITL30YR     972
# GTITL10YR     981
# GTITL2YR      998
# GTJPY30YR     794
# GTJPY10YR     741
# GTJPY2YR      533
# GTGBP30Y      896
# GTGBP20Y      933
# GTGBP2Y       932
# LUMSTRUU     1104
# LMBITR       1108
# LUACTRUU     1105
# LF98TRUU     1099
# LG30TRUU     1110
# LP01TREU     1106
# EMUSTRUU     1110
# LF94TRUU      950
# MXUS         1107
# MXEU         1035
# MXJP         1102
# MXBR         1107
# MXRU         1105
# MXIN         1106
# MXCN         1033
# dtype: int64

# %%
data.describe()
# Display summary statistics
# Out:
#                  Y     XAU BGNL     ECSURPUS          BDIY          CRY  \
# count  1111.000000  1111.000000  1111.000000   1111.000000  1111.000000
# mean      0.213321   987.463744     0.036153   2259.860486   245.247670
# std       0.409837   494.623740     0.349453   2017.811888    68.278066
# min       0.000000   256.680000    -0.974000    291.000000   106.293000
# 25%       0.000000   433.740000    -0.191000    990.000000   184.705550
# 50%       0.000000  1137.800000     0.035000   1518.000000   234.560000
# 75%       0.000000  1324.825000     0.260500   2685.500000   301.539500
# max       1.000000  2006.910000     0.991000  11793.000000   467.570000
#
#                DXY          JPY          GBP          Cl1          VIX  ...  \
# count  1111.000000  1111.000000  1111.000000  1111.000000  1111.000000  ...
# mean     90.934982   106.605734     1.569661    60.708101    19.992169  ...
# std      11.379095    12.840754     0.212344    25.900813     8.642157  ...
# ...

# %%
data.isnull().sum()
# check for missing values
# Out:
# Y            0
# Data         0
# XAU BGNL     0
# ECSURPUS     0
# BDIY         0
# CRY          0
# DXY          0
# JPY          0
# GBP          0
# Cl1          0
# VIX          0
# USGG30YR     0
# GT10         0
# USGG2YR      0
# USGG3M       0
# US0001M      0
# GTDEM30Y     0
# GTDEM10Y     0
# GTDEM2Y      0
# EONIA        0
# GTITL30YR    0
# GTITL10YR    0
# GTITL2YR     0
# GTJPY30YR    0
# GTJPY10YR    0
# GTJPY2YR     0
# GTGBP30Y     0
# GTGBP20Y     0
# GTGBP2Y      0
# LUMSTRUU     0
# LMBITR       0
# LUACTRUU     0
# LF98TRUU     0
# LG30TRUU     0
# LP01TREU     0
# EMUSTRUU     0
# LF94TRUU     0
# MXUS         0
# MXEU         0
# MXJP         0
# MXBR         0
# MXRU         0
# MXIN         0
# MXCN         0
# dtype: int64

# %%
download_data.isnull().sum()
# Out:
# 4
# NaN                1144
# NaN                1146
# Ticker                2
# XAU BGNL Curncy       2
# ECSURPUS Index       41
# BDIY Index            4
# CRY Index             4
# DXY Curncy            4
# JPY Curncy            4
# GBP Curncy            4
# Cl1 Comdty            4
# VIX Index             4
# USGG30YR Index        4
# GT10 Govt             4
# USGG2YR Index         4
# USGG3M Index          4
# US0001M Index         4
# GTDEM30Y Govt         4
# GTDEM10Y Govt         4
# GTDEM2Y Govt          4
# EONIA Index           4
# GTITL30YR Corp       31
# GTITL10YR Corp       31
# GTITL2YR Corp        31
# GTJPY30YR Corp       23
# GTJPY10YR Corp        4
# GTJPY2YR Corp         4
# GTGBP30Y Govt         4
# GTGBP20Y Govt         4
# GTGBP2Y Govt          4
# LUMSTRUU Index        4
# LMBITR Index          4
# LUACTRUU Index        4
# LF98TRUU Index        4
# LG30TRUU Index        4
# LP01TREU Index        4
# EMUSTRUU Index        4
# LF94TRUU Index        5
# ...

# %%
# if there were missing values you could use the below code
# to calculate the percentage for each column
# (df.isnull().sum()/(len(df)))*100
((download_data.isnull().sum())/(len(download_data)))*100
# Out:
# 4
# NaN                99.133449
# NaN                99.306759
# Ticker              0.173310
# XAU BGNL Curncy     0.173310
# ECSURPUS Index      3.552860
# BDIY Index          0.346620
# CRY Index           0.346620
# DXY Curncy          0.346620
# JPY Curncy          0.346620
# GBP Curncy          0.346620
# Cl1 Comdty          0.346620
# VIX Index           0.346620
# USGG30YR Index      0.346620
# GT10 Govt           0.346620
# USGG2YR Index       0.346620
# USGG3M Index        0.346620
# US0001M Index       0.346620
# GTDEM30Y Govt       0.346620
# GTDEM10Y Govt       0.346620
# GTDEM2Y Govt        0.346620
# EONIA Index         0.346620
# GTITL30YR Corp      2.686308
# GTITL10YR Corp      2.686308
# GTITL2YR Corp       2.686308
# GTJPY30YR Corp      1.993068
# GTJPY10YR Corp      0.346620
# GTJPY2YR Corp       0.346620
# GTGBP30Y Govt       0.346620
# GTGBP20Y Govt       0.346620
# GTGBP2Y Govt        0.346620
# LUMSTRUU Index      0.346620
# LMBITR Index        0.346620
# ...

# %%
# Convert data column to simple date
data['Data'] = pd.to_datetime(data['Data'])

# %%
# Create the figure and axes
fig, ax1 = plt.subplots()

# Create Bar chart with Y values
ax1.bar(data['Data'], data["Y"], color="r", alpha=0.7, label="Anomaly Data")

# Create second y-axis for the line chart
ax2 = ax1.twinx()

# Create line chart
ax2.plot(data["Data"], data["VIX"], color="b", label="VIX")

# Set labels and title
ax1.set_xlabel("Date")
ax1.set_ylabel("Anomaly Data")
ax2.set_ylabel("VIX")
plt.title("VIX Stock Anomalies")

# Add legend
fig.legend(loc='upper right')

# show the plot
plt.show()

# %%
# Create the figure and axes
fig, ax1 = plt.subplots()

# Create Bar chart with Y values
ax1.bar(data['Data'], data["Y"], color="r", alpha=0.7, label="Anomaly Data")

# Create second y-axis for the line chart
ax2 = ax1.twinx()

# Create line chart
ax2.plot(data["Data"], data["JPY"], color="b", label="JPY")

# Set labels and title
ax1.set_xlabel("Date")
ax1.set_ylabel("Anomaly Data")
ax2.set_ylabel("VIX")
plt.title("JPY vs Stock Anomalies")

# Add legend
fig.legend(loc='upper right')

# show the plot
plt.show()

# %% [markdown]
# ## Step 4: Correlation Analysis
# See how the data relates to the rest of the data. This can help decide what columns to keep and what columns/data won't be very helpful.
#
# df.corr(method, min_periods,numeric_only )
#
# - *method* : In method we can choose any one from {'pearson', 'kendall', 'spearman'} pearson is the standard correlation coefficient matrix i.e default
# - *min_periods* : int This is optional. Defines th eminimum number of observations required per pair.
# - *numeric_only* : Default is False, Defines we want to compare only numeric or categorical object also
#
# #### Correlation Coefficient Relationship
# - **Exactly –1** : A perfect negative, downward-sloping linear relationship
#
# - **–0.70** : A strong negative, downward-sloping linear relationship
#
# - **–0.50** : A moderate negative, downhill-sloping relationship
#
# - **–0.30** A weak negative, downhill-sloping linear relationship
#
# - **0** : No linear relationship
#
# - **+0.30** : A weak positive, upward-sloping linear relationship
#
# - **+0.50** : A moderate positive, upward-sloping linear relationship
#
# - **+0.70** : A strong positive, upward-sloping linear relationship
#
# - **Exactly +1** : A perfect positive, upward-sloping linear relationship

# %%
corr = data.corr(method = 'pearson')
corr
# the data below shows how vix has the closest positive correlation with the anomaly data
# Out:
#                   Y      Data  XAU BGNL  ECSURPUS      BDIY       CRY  \
# Y          1.000000 -0.136997 -0.011535 -0.090772 -0.083440 -0.074102
# Data      -0.136997  1.000000  0.883657  0.076315 -0.333763 -0.214607
# XAU BGNL  -0.011535  0.883657  1.000000  0.114798 -0.315007  0.015316
# ECSURPUS  -0.090772  0.076315  0.114798  1.000000 -0.102022 -0.139779
# BDIY      -0.083440 -0.333763 -0.315007 -0.102022  1.000000  0.596182
# CRY       -0.074102 -0.214607  0.015316 -0.139779  0.596182  1.000000
# DXY        0.103227 -0.226178 -0.428891  0.074835 -0.441793 -0.798564
# JPY       -0.151197 -0.223273 -0.576191 -0.070422  0.062822 -0.412364
# GBP       -0.093201 -0.543655 -0.422084 -0.188233  0.756718  0.793954
# Cl1       -0.070141  0.292058  0.515215 -0.016245  0.286396  0.785614
# VIX        0.598432 -0.183323 -0.075873 -0.094127 -0.045367 -0.190060
# USGG30YR   0.019255 -0.932811 -0.868696 -0.015927  0.390852  0.256228
# ...

# %%
data.corr().unstack().sort_values().drop_duplicates()
# Out:
# LMBITR    GTDEM30Y   -0.980298
#           GTDEM10Y   -0.979988
# GTDEM30Y  LUACTRUU   -0.977186
# GTDEM10Y  LUACTRUU   -0.975891
# GTDEM30Y  EMUSTRUU   -0.970651
#                         ...
# LMBITR    EMUSTRUU    0.995091
# LG30TRUU  EMUSTRUU    0.995281
# LUACTRUU  LMBITR      0.996166
# LF98TRUU  LG30TRUU    0.998491
# Y         Y           1.000000
# Length: 947, dtype: float64

# %%
data.corrwith(data["Y"]).sort_values(ascending=False)
# To choose stocks that show the most correlation with anomalies that occur
# Out:
# Y            1.000000
# VIX          0.598432
# GTITL2YR     0.304528
# GTITL10YR    0.297573
# GTITL30YR    0.295000
# EONIA        0.180311
# GTDEM30Y     0.141537
# GTDEM10Y     0.139933
# GTJPY10YR    0.133660
# GTDEM2Y      0.130607
# GTJPY30YR    0.114555
# GTJPY2YR     0.112314
# DXY          0.103227
# GTGBP20Y     0.100142
# GTGBP30Y     0.099777
# GTGBP2Y      0.035010
# USGG30YR     0.019255
# US0001M      0.015379
# GT10        -0.004776
# XAU BGNL    -0.011535
# USGG3M      -0.025935
# USGG2YR     -0.034909
# MXBR        -0.043429
# Cl1         -0.070141
# CRY         -0.074102
# BDIY        -0.083440
# ECSURPUS    -0.090772
# GBP         -0.093201
# LUMSTRUU    -0.104897
# Data        -0.136997
# LMBITR      -0.143607
# MXRU        -0.148848
# MXCN        -0.149581
# JPY         -0.151197
# LUACTRUU    -0.153544
# LF94TRUU    -0.156550
# EMUSTRUU    -0.169475
# MXIN        -0.188942
# LF98TRUU    -0.189661
# MXUS        -0.193928
# LG30TRUU    -0.197232
# ...

# %% [markdown]
# ## Step 5: Data Reduction
# Drop the data (columns or variables) that aren't adding value to the analysis
#
# For this project there are more columns to drop then to keep so instead of using the drop function I will be recreating the dataframe (data) with only the columns I wish to use.
#
# **Option 1: Use Column Names**
# dataframeName[["columnName1", ... , "columnNameN"]]
#
# **Option 2: Use Column Index #**
# cols = [0,1,10]
# dataframeName[dataseframeName.columns[cols]]

# %%
# Remove column from data
# df = df.drop(['columnName'], axis=1)

# %%
# Specify columns to use
df = data[["Y", "Data", "VIX"]]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1111 entries, 0 to 1110
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Y          1111 non-null   int64
#  1   Data       1111 non-null   datetime64[ns]
#  2   VIX        1111 non-null   float64
#  3   GTITL2YR   1111 non-null   float64
#  4   GTITL10YR  1111 non-null   float64
#  5   GTITL30YR  1111 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 52.2 KB

# %%
# Use 'Data' to extract year and week number
df['Year'] = df['Data'].dt.year
df['Week'] = df['Data'].dt.week
df['Day'] = df['Data'].dt.day

# For now, we can use 'VIX' as a feature and the target anomaly or 'Y'
X = df[['VIX', 'Year', 'Week', 'Day']]
y = df['Y']

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0, shuffle=False)

# %%
data.groupby('Y').agg(['mean', 'median', 'min', 'max', 'std'])
# Out:
#                            Data                                            \
#                            mean              median        min        max
# Y
# 0 2011-02-07 03:49:00.961098240 2011-03-04 12:00:00 2000-01-11 2021-04-20
# 1 2009-01-17 08:54:41.012658176 2009-02-24 00:00:00 2000-02-08 2020-11-03
#
#                                       VIX                                  \
#                            std       mean median    min    max        std
# Y
# 0 2227 days 03:51:06.678170208  17.300263  16.01   9.43  32.88   5.194502
# 1 2221 days 01:19:11.625088288  29.919283  27.05  13.71  75.91  11.210110
#
#    ... GTITL10YR                                 GTITL30YR                 \
#    ...      mean  median    min    max       std      mean  median    min
# Y  ...
# 0  ...  3.453836  3.9435  0.512  5.889  1.383427  4.230992  4.5875  1.386
# 1  ...  4.517747  4.8460  0.699  7.209  1.457602  5.148540  5.4150  1.573
#
#
#      max       std
# Y
# 0  6.693  1.196397
# ...

# %%
print(data.index)
# Out:
# RangeIndex(start=0, stop=1111, step=1)

# %% [markdown]
# ## [TimesFM-2.0 from Google](https://huggingface.co/google/timesfm-2.0-500m-pytorch)
# A pretrained time-series foundation model for forecasting
# - works better with GPU
# - Requirements:
#   - `ds` column for date/time
#   - `unique_id` column for time series name
# - Can include:
#   - `freq` for frequency of the `ds` column (hourly, daily, weekly, etc.)
#   - `value_name` indicates the column with values for forecasting
#   - `num_jobs` limits the # of series forcasted asynchronously
#
# ### [GitHub](https://github.com/google-research/timesfm/tree/master)
# - [Finetuning Walkthrough Notebook](https://github.com/google-research/timesfm/blob/master/notebooks/finetuning.ipynb)
#
# ### [Hugging Face](https://huggingface.co/google/timesfm-2.0-500m-pytorch)
#
#
# ### Separate Examples of people using TimeFM
# - [Ex1 GitHub](https://github.com/statmike/vertex-ai-mlops/blob/main/Applied%20Forecasting/TimesFM%20-%20Time%20Series%20Foundation%20Model.ipynb)
# - [Ex2 GitHub](https://github.com/gabaid971/ts-forecaster/blob/main/ts_forecaster.ipynb)

# %%
import timesfm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-f815183c60a1> in <cell line: 1>()
# ----> 1 import timesfm
#
# ModuleNotFoundError: No module named 'timesfm'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ### No module names 'timesfm'
#
# After researching, I tried:
# 1. `!pip install timesfm` and `%pip install timesfm`
# **Result:** greeted with runtime issues and colab crashes.
# 2. Found Video tutorial ["TimesFM Time Series Forcasting"](https://www.youtube.com/watch?v=7QqUw29bJmc) that showed how to install it directly from the GitHub as adviced by the TimesFM developers
# ```
# !pip install -e git+https://github.com/google-research/timesfm.git@main#egg=timesfm
#
# ```

# %%
# !pip install timesfm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.6/821.6 kB 40.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 59.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 7.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.7.1
#     Uninstalling traitlets-5.7.1:
#       Successfully uninstalled traitlets-5.7.1
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.34.0
#     Uninstalling ipython-7.34.0:
#       Successfully uninstalled ipython-7.34.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# !pip install -q git+https://github.com/google-research/timesfm.git@master#egg=timesfm
# Out:
# Obtaining timesfm from git+https://github.com/google-research/timesfm.git@master#egg=timesfm
#   Updating ./src/timesfm clone (to revision master)
#   Running command git fetch -q --tags
#   Running command git reset --hard -q a3ab7873e9b646acddfe86d2b691cf218db28f48
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.6/821.6 kB 32.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 61.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 8.9 MB/s eta 0:00:00
# ...
#   Building editable for timesfm (pyproject.toml) ... done
# ...

# %%
import plotly.express as px
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_pacf
from prophet import Prophet
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, root_mean_squared_error
import timesfm

import warnings
warnings.filterwarnings('ignore')

import logging
cmdstanpy_logger = logging.getLogger("cmdstanpy")
absl_logger = logging.getLogger("absl")
cmdstanpy_logger.disabled = True
absl_logger.disabled = True
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-b556a5b613cf> in <cell line: 11>()
#       9 from sklearn.ensemble import RandomForestRegressor
#      10 from sklearn.metrics import mean_absolute_error, root_mean_squared_error
# ---> 11 import timesfm
#      12
#      13 import warnings
#
# ModuleNotFoundError: No module named 'timesfm'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# # Google Colab Freeze
# Colab stopped connecting to a runtime before completion of this project. Code below this point has not been ran and is just where I was heading.
#
# Restarting colab, device and runtime didn't work to fix issue

# %%
tfm = timesfm.TimesFm(
    context_len=480,
    horizon_len=14,
    input_patch_len=32,
    output_patch_len=128,
    num_layers=20,
    model_dims=1280,
    backend="cpu",
)

tfm.load_from_checkpoint(repo_id="google/timesfm-1.0-200m")

# %% [markdown]
# ## Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
lin_reg=LinearRegression()
lin_reg.fit(X_train,y_train)
